# %% [markdown]
# ## Неострый

# %%
@interact
def _(
    sigma=FloatSlider(min=0, value=1, max=10), 
    radius=FloatSlider(min=1, value=1, max=10), 
    amount=FloatSlider(value=1, min=0, max=10)
    ):
    blurred = filters.blur(image, sigma)
    
    # blurred = noised
    left, right = panels()
    imshow(blurred, left)
    imshow(filters.unsharp(blurred, radius, amount), right)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='sigma', max=10.0), FloatSlider(value=1.0, descriptio…
